# %% [markdown]
# <a href="https://colab.research.google.com/github/Maddi-Abhay-Sai/Addition-of-2-numbers-in-java/blob/main/Practical1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practical 1:Introduction to Python and Environment Setup

# %%
#Practical 1
'''This is my First Python Code'''
import sys
print("Python version is:",sys.version)
# Out:
# Python version is: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
name="M.Abhay Sai"
age=20
city="Rajkot"
print("Name  :",name)
print("Age  :",age)
print("City  :",city)
# Out:
# Name  : M.Abhay Sai
# Age  : 20
# City  : Rajkot

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
city=input("Enter your city:")
print("Name  :",name)
print("Age  :",age)
print("City  :",city)
# Out:
# Enter your name:M.Abhay Sai
# Enter your age:20
# Enter your city:Rajkot
# Name  : M.Abhay Sai
# Age  : 20
# City  : Rajkot

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
city = input("Enter your city: ")
age1=age+1
print("\nHello",name + "!")
print("Next year,you will be",age1,"years-old")
print("You are from",city+".")
# Out:
# Enter your name:M.Abhay Sai
# Enter your age:20
# Enter your city: Rajkot
#
# Hello M.Abhay Sai!
# Next year,you will be 21 years-old
# You are from Rajkot.

# %%
print("Practical 1A")
'''This is my First Python Code'''

# Import the sys module to access system-specific information
import sys

# Print the current Python version being used
print("Python version is:\n",sys.version)

# Print a simple greeting message
print("Hello World!")

print("\nPractical 1B")

# Declare and initialize variables with fixed (hard-coded) values
name="M.Abhay Sai"
age=20
city="Rajkot"

# Display the values of the variables
print("Name  :",name)
print("Age  :",age)
print("City  :",city)

print("\nPractical 1C")


# Take user input for name (stored as string by default)
name=input("Enter your name:")

# Take user input for age and convert it from string to integer
age=int(input("Enter your age:"))

# Take user input for city (stored as string)
city=input("Enter your city:")

# Display the values entered by the user
print("Name  :",name)
print("Age  :",age)
print("City  :",city)

print("\nPractical 1D")


# Take user input for name
name=input("Enter your name:")

# Take user input for age and convert it to an integer for calculations
age=int(input("Enter your age:"))

# Take user input for city
city = input("Enter your city: ")

# Calculate next year's age by adding 1 to the current age
age1=age+1

# Print a personalized greeting using the entered name
print("\nHello",name + "!")

# Print the calculated age for next year
print("Next year,you will be",age1,"years-old")

# Print the city entered by the user
print("You are from",city+".")
# Out:
# Practical 1A
# Python version is:
#  3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Hello World!
#
# Practical 1B
# Name  : M.Abhay Sai
# Age  : 20
# City  : Rajkot
#
# Practical 1C
# Enter your name:M.Abhay Sai
# Enter your age:20
# Enter your city:Rajkot
# Name  : M.Abhay Sai
# Age  : 20
# City  : Rajkot
#
# Practical 1D
# Enter your name:M.Abhay Sai
# Enter your age:20
# Enter your city: Rajkot
#
# Hello M.Abhay Sai!
# Next year,you will be 21 years-old
# You are from Rajkot.
